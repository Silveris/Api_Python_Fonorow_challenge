# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
temps = []
humidities = []
cloudinessess = []
windSpeeds = []
cityLats = []
cityLngs = []
dates = []
countries = []
names = []

# %%
print('Beginning Data Retrieval')
print('--------------------------------------')
for city in cities:
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
    response = requests.get(url).json()
    print(f'Attempting to save data for {city} :')
    try:
        names.append(response['name'])
        temps.append(response['main']['temp_max'])
        humidities.append(response['main']['humidity'])
        cloudinessess.append(response['clouds']['all'])
        windSpeeds.append(response['wind']['speed'])
        cityLats.append(response['coord']['lat'])
        cityLngs.append(response['coord']['lon'])
        dates.append(response['dt'])
        countries.append(response['sys']['country'])
    except KeyError:
        print(f'failed to find all info for {city}, skipping')
    
print('--------------------------------------')
print('Data Retrieval Complete')
print('--------------------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------------------
# Attempting to save data for anadyr :
# Attempting to save data for carnarvon :
# Attempting to save data for saldanha :
# Attempting to save data for codrington :
# Attempting to save data for rikitea :
# Attempting to save data for mahebourg :
# Attempting to save data for cape town :
# Attempting to save data for kavaratti :
# Attempting to save data for chokurdakh :
# Attempting to save data for vadum :
# Attempting to save data for ushuaia :
# Attempting to save data for labutta :
# failed to find all info for labutta, skipping
# Attempting to save data for nizhniye vyazovyye :
# Attempting to save data for barentsburg :
# failed to find all info for barentsburg, skipping
# Attempting to save data for velikooktyabrskiy :
# Attempting to save data for taolanaro :
# failed to find all info for taolanaro, skipping
# Attempting to save data for saint george :
# Attempting to save data for ola :
# Attempting to save data for terrace :
# Attempting to save data for bonaventure :
# Attempting to save data for east london :
# Attempting to save data for pacific grove :
# Attempting to save data for tasiilaq :
# Attempting to save data for hermanus :
# Attempting to save data for hilo :
# Attempting to save data for zlobin :
# Attempting to save data for butte :
# Attempting to save data for norman wells :
# Attempting to save data for port alfred :
# Attempting to save data for nantucket :
# Attempting to save data for albany :
# Attempting to save data for port blair :
# Attempting to save data for busselton :
# Attempting to save data for atuona :
# Attempting to save data for airai :
# Attempting to save data for los llanos de aridane :
# Attempting to save data for kapaa :
# Attempting to save data for nikolskoye :
# Attempting to save data for mar del plata :
# Attempting to save data for souillac :
# Attempting to save data for ilulissat :
# Attempting to save data for tiksi :
# Attempting to save data for shimoda :
# Attempting to save data for avarua :
# Attempting to save data for takaka :
# Attempting to save data for upernavik :
# Attempting to save data for dale :
# Attempting to save data for saskylakh :
# Attempting to save data for hithadhoo :
# Attempting to save data for vaini :
# Attempting to save data for kathmandu :
# Attempting to save data for laguna :
# Attempting to save data for uribia :
# Attempting to save data for castro :
# Attempting to save data for sao raimundo das mangabeiras :
# Attempting to save data for xining :
# Attempting to save data for yellowknife :
# Attempting to save data for manaure :
# Attempting to save data for mataura :
# Attempting to save data for luderitz :
# Attempting to save data for chuy :
# Attempting to save data for punta arenas :
# Attempting to save data for puerto ayora :
# Attempting to save data for alyangula :
# Attempting to save data for cayenne :
# Attempting to save data for severo-kurilsk :
# Attempting to save data for yulara :
# Attempting to save data for am timan :
# Attempting to save data for nabire :
# Attempting to save data for coquimbo :
# Attempting to save data for oud-beijerland :
# Attempting to save data for suoyarvi :
# Attempting to save data for yar-sale :
# Attempting to save data for turukhansk :
# Attempting to save data for samusu :
# failed to find all info for samusu, skipping
# Attempting to save data for sibolga :
# Attempting to save data for lagoa formosa :
# Attempting to save data for vila franca do campo :
# Attempting to save data for provideniya :
# Attempting to save data for punta cardon :
# Attempting to save data for grand gaube :
# Attempting to save data for charters towers :
# Attempting to save data for isangel :
# Attempting to save data for suntar :
# Attempting to save data for kloulklubed :
# Attempting to save data for jamestown :
# Attempting to save data for saint-philippe :
# Attempting to save data for kaitangata :
# Attempting to save data for leningradskiy :
# Attempting to save data for kahului :
# Attempting to save data for mys shmidta :
# failed to find all info for mys shmidta, skipping
# Attempting to save data for faanui :
# Attempting to save data for sao filipe :
# Attempting to save data for sopelana :
# Attempting to save data for grand centre :
# failed to find all info for grand centre, skipping
# Attempting to save data for necochea :
# Attempting to save data for coahuayana :
# Attempting to save data for gallup :
# Attempting to save data for longyearbyen :
# Attempting to save data for atar :
# Attempting to save data for marcona :
# failed to find all info for marcona, skipping
# Attempting to save data for apodi :
# Attempting to save data for gwadar :
# Attempting to save data for kropotkin :
# Attempting to save data for georgetown :
# Attempting to save data for shonguy :
# Attempting to save data for chany :
# Attempting to save data for tilichiki :
# Attempting to save data for salalah :
# Attempting to save data for aromashevo :
# Attempting to save data for cap malheureux :
# Attempting to save data for sabang :
# Attempting to save data for bredasdorp :
# Attempting to save data for ischia :
# Attempting to save data for haibowan :
# failed to find all info for haibowan, skipping
# Attempting to save data for ribeira grande :
# Attempting to save data for katsuura :
# Attempting to save data for binzhou :
# Attempting to save data for qaanaaq :
# Attempting to save data for grindavik :
# Attempting to save data for kibaya :
# Attempting to save data for new norfolk :
# Attempting to save data for illoqqortoormiut :
# failed to find all info for illoqqortoormiut, skipping
# Attempting to save data for hofn :
# Attempting to save data for pailon :
# Attempting to save data for general pico :
# Attempting to save data for hailar :
# Attempting to save data for sisimiut :
# Attempting to save data for naze :
# Attempting to save data for husavik :
# Attempting to save data for faridpur :
# Attempting to save data for sataua :
# failed to find all info for sataua, skipping
# Attempting to save data for bluff :
# Attempting to save data for banda aceh :
# Attempting to save data for vila velha :
# Attempting to save data for port elizabeth :
# Attempting to save data for yirol :
# failed to find all info for yirol, skipping
# Attempting to save data for raton :
# Attempting to save data for hobart :
# Attempting to save data for narsaq :
# Attempting to save data for hami :
# Attempting to save data for yinchuan :
# Attempting to save data for sampit :
# Attempting to save data for nador :
# Attempting to save data for kijang :
# Attempting to save data for hasaki :
# Attempting to save data for pevek :
# Attempting to save data for bethel :
# Attempting to save data for tsihombe :
# failed to find all info for tsihombe, skipping
# Attempting to save data for kudahuvadhoo :
# Attempting to save data for biak :
# Attempting to save data for fukue :
# Attempting to save data for sinjai :
# Attempting to save data for belushya guba :
# failed to find all info for belushya guba, skipping
# Attempting to save data for tabiauea :
# failed to find all info for tabiauea, skipping
# Attempting to save data for ndioum :
# Attempting to save data for havre-saint-pierre :
# Attempting to save data for barrow :
# Attempting to save data for asyut :
# Attempting to save data for keetmanshoop :
# Attempting to save data for guerrero negro :
# Attempting to save data for vanderhoof :
# Attempting to save data for beringovskiy :
# Attempting to save data for constitucion :
# Attempting to save data for amderma :
# failed to find all info for amderma, skipping
# Attempting to save data for sao joao evangelista :
# Attempting to save data for zhangjiakou :
# Attempting to save data for carutapera :
# Attempting to save data for caravelas :
# Attempting to save data for namatanai :
# Attempting to save data for kruisfontein :
# Attempting to save data for saleaula :
# failed to find all info for saleaula, skipping
# Attempting to save data for piacabucu :
# Attempting to save data for arraial do cabo :
# Attempting to save data for amapa :
# Attempting to save data for andenes :
# Attempting to save data for ratnagiri :
# Attempting to save data for lorengau :
# Attempting to save data for hamilton :
# Attempting to save data for tumannyy :
# failed to find all info for tumannyy, skipping
# Attempting to save data for la ronge :
# Attempting to save data for parintins :
# Attempting to save data for coari :
# Attempting to save data for tuktoyaktuk :
# Attempting to save data for tazovskiy :
# Attempting to save data for lagoa :
# Attempting to save data for ruatoria :
# failed to find all info for ruatoria, skipping
# Attempting to save data for khatanga :
# Attempting to save data for hervey bay :
# Attempting to save data for butaritari :
# Attempting to save data for noumea :
# Attempting to save data for mbini :
# Attempting to save data for yerofey pavlovich :
# Attempting to save data for srednekolymsk :
# Attempting to save data for balykshi :
# failed to find all info for balykshi, skipping
# Attempting to save data for riyadh :
# Attempting to save data for valdivia :
# Attempting to save data for neman :
# Attempting to save data for buzdyak :
# Attempting to save data for bengkulu :
# Attempting to save data for okakarara :
# Attempting to save data for sangar :
# Attempting to save data for geraldton :
# Attempting to save data for esperance :
# Attempting to save data for qarayeri :
# Attempting to save data for ambulu :
# Attempting to save data for evensk :
# Attempting to save data for nicoya :
# Attempting to save data for ambovombe :
# Attempting to save data for toliary :
# failed to find all info for toliary, skipping
# Attempting to save data for cheuskiny :
# failed to find all info for cheuskiny, skipping
# Attempting to save data for tual :
# Attempting to save data for north bend :
# Attempting to save data for ambodifototra :
# failed to find all info for ambodifototra, skipping
# Attempting to save data for aflu :
# failed to find all info for aflu, skipping
# Attempting to save data for muravlenko :
# Attempting to save data for belaya gora :
# Attempting to save data for aksaray :
# Attempting to save data for mitu :
# Attempting to save data for saint-pierre :
# Attempting to save data for sola :
# Attempting to save data for gander :
# Attempting to save data for cocobeach :
# Attempting to save data for bambous virieux :
# Attempting to save data for lebu :
# Attempting to save data for jeremie :
# Attempting to save data for utiroa :
# failed to find all info for utiroa, skipping
# Attempting to save data for nanortalik :
# Attempting to save data for maniitsoq :
# Attempting to save data for newport :
# Attempting to save data for marawi :
# Attempting to save data for dingle :
# Attempting to save data for mandalgovi :
# Attempting to save data for lisakovsk :
# Attempting to save data for timizart :
# Attempting to save data for salinopolis :
# Attempting to save data for palauig :
# Attempting to save data for attawapiskat :
# failed to find all info for attawapiskat, skipping
# Attempting to save data for kati :
# Attempting to save data for vanersborg :
# Attempting to save data for ngong :
# Attempting to save data for yatou :
# Attempting to save data for mafra :
# Attempting to save data for krasnyy yar :
# Attempting to save data for pakwach :
# failed to find all info for pakwach, skipping
# Attempting to save data for wana :
# Attempting to save data for barawe :
# failed to find all info for barawe, skipping
# Attempting to save data for beloha :
# Attempting to save data for half moon bay :
# Attempting to save data for madimba :
# Attempting to save data for mentok :
# failed to find all info for mentok, skipping
# Attempting to save data for kodiak :
# Attempting to save data for westport :
# Attempting to save data for kamaishi :
# Attempting to save data for iqaluit :
# Attempting to save data for richards bay :
# Attempting to save data for antakya :
# Attempting to save data for manaus :
# Attempting to save data for adrar :
# Attempting to save data for lakselv :
# Attempting to save data for mayo :
# Attempting to save data for brae :
# Attempting to save data for sekoma :
# Attempting to save data for muros :
# Attempting to save data for ozimek :
# Attempting to save data for lasa :
# Attempting to save data for kilosa :
# Attempting to save data for cidreira :
# Attempting to save data for cherskiy :
# Attempting to save data for miri :
# Attempting to save data for kavieng :
# Attempting to save data for soc trang :
# Attempting to save data for cuamba :
# Attempting to save data for mahajanga :
# Attempting to save data for gasa :
# Attempting to save data for lashio :
# Attempting to save data for deputatskiy :
# Attempting to save data for cheyenne :
# Attempting to save data for tolbazy :
# Attempting to save data for san quintin :
# Attempting to save data for paucartambo :
# failed to find all info for paucartambo, skipping
# Attempting to save data for uhlove :
# Attempting to save data for sitka :
# Attempting to save data for ancud :
# Attempting to save data for kununurra :
# Attempting to save data for grand river south east :
# failed to find all info for grand river south east, skipping
# Attempting to save data for hovd :
# Attempting to save data for ust-barguzin :
# Attempting to save data for sorvag :
# failed to find all info for sorvag, skipping
# Attempting to save data for tuatapere :
# Attempting to save data for teguldet :
# Attempting to save data for klaksvik :
# Attempting to save data for floro :
# Attempting to save data for nizhneyansk :
# failed to find all info for nizhneyansk, skipping
# Attempting to save data for high level :
# Attempting to save data for labuhan :
# Attempting to save data for hualmay :
# Attempting to save data for sterling :
# Attempting to save data for morropon :
# Attempting to save data for mount gambier :
# Attempting to save data for inirida :
# Attempting to save data for cabo san lucas :
# Attempting to save data for monrovia :
# Attempting to save data for bonthe :
# Attempting to save data for benghazi :
# Attempting to save data for ahipara :
# Attempting to save data for stornoway :
# Attempting to save data for alta floresta :
# Attempting to save data for mokrousovo :
# Attempting to save data for kpandae :
# Attempting to save data for san patricio :
# Attempting to save data for nome :
# Attempting to save data for thompson :
# Attempting to save data for kalynivka :
# Attempting to save data for sainte-suzanne :
# Attempting to save data for constantine :
# Attempting to save data for santo andre :
# Attempting to save data for taoudenni :
# Attempting to save data for skjervoy :
# Attempting to save data for sotnikovo :
# Attempting to save data for asosa :
# Attempting to save data for dzhusaly :
# failed to find all info for dzhusaly, skipping
# Attempting to save data for palmer :
# Attempting to save data for lompoc :
# Attempting to save data for onega :
# Attempting to save data for mushie :
# Attempting to save data for kita :
# Attempting to save data for itarema :
# Attempting to save data for alotau :
# failed to find all info for alotau, skipping
# Attempting to save data for juneau :
# Attempting to save data for boende :
# Attempting to save data for charleville :
# Attempting to save data for masunga :
# Attempting to save data for ardahan :
# Attempting to save data for nikolayevsk-na-amure :
# Attempting to save data for porosozero :
# Attempting to save data for goma :
# Attempting to save data for tommot :
# Attempting to save data for ballina :
# Attempting to save data for dunedin :
# Attempting to save data for avera :
# Attempting to save data for nagram :
# Attempting to save data for moose factory :
# Attempting to save data for tarauaca :
# Attempting to save data for along :
# Attempting to save data for rwamagana :
# Attempting to save data for ostrovnoy :
# Attempting to save data for weihai :
# Attempting to save data for acaponeta :
# Attempting to save data for tagusao :
# Attempting to save data for baykit :
# Attempting to save data for kamogawa :
# Attempting to save data for portland :
# Attempting to save data for berlevag :
# Attempting to save data for clyde river :
# Attempting to save data for vanino :
# Attempting to save data for innisfail :
# Attempting to save data for porto velho :
# Attempting to save data for shetpe :
# Attempting to save data for mabai :
# Attempting to save data for tongliao :
# Attempting to save data for santona :
# Attempting to save data for buala :
# Attempting to save data for verkhnevilyuysk :
# Attempting to save data for fortuna :
# Attempting to save data for nizhnevartovsk :
# Attempting to save data for tyrma :
# Attempting to save data for burica :
# failed to find all info for burica, skipping
# Attempting to save data for bauru :
# Attempting to save data for paamiut :
# Attempting to save data for veraval :
# Attempting to save data for porto santo :
# Attempting to save data for urucara :
# Attempting to save data for blois :
# Attempting to save data for chapais :
# Attempting to save data for mamallapuram :
# Attempting to save data for reconquista :
# Attempting to save data for nguiu :
# failed to find all info for nguiu, skipping
# Attempting to save data for wao :
# Attempting to save data for siderno :
# Attempting to save data for atsiki :
# failed to find all info for atsiki, skipping
# Attempting to save data for altay :
# Attempting to save data for buchanan :
# Attempting to save data for iranshahr :
# Attempting to save data for oranjemund :
# Attempting to save data for douglas :
# Attempting to save data for nelson bay :
# Attempting to save data for majene :
# Attempting to save data for burgeo :
# Attempting to save data for aberdeen :
# Attempting to save data for katherine :
# Attempting to save data for rio gallegos :
# Attempting to save data for benicarlo :
# Attempting to save data for nouadhibou :
# Attempting to save data for porbandar :
# Attempting to save data for san carlos de bariloche :
# Attempting to save data for yeppoon :
# Attempting to save data for arman :
# Attempting to save data for teya :
# Attempting to save data for cagayan de tawi-tawi :
# failed to find all info for cagayan de tawi-tawi, skipping
# Attempting to save data for mavur :
# failed to find all info for mavur, skipping
# Attempting to save data for zaplyusye :
# failed to find all info for zaplyusye, skipping
# Attempting to save data for roald :
# Attempting to save data for coihaique :
# Attempting to save data for bryan :
# Attempting to save data for sentyabrskiy :
# failed to find all info for sentyabrskiy, skipping
# Attempting to save data for itupiranga :
# Attempting to save data for riaba :
# failed to find all info for riaba, skipping
# Attempting to save data for gravdal :
# Attempting to save data for vao :
# Attempting to save data for dzerzhinsk :
# Attempting to save data for lazaro cardenas :
# Attempting to save data for san jose :
# Attempting to save data for shenjiamen :
# Attempting to save data for amahai :
# Attempting to save data for saint anthony :
# Attempting to save data for qasigiannguit :
# Attempting to save data for tasbuget :
# failed to find all info for tasbuget, skipping
# Attempting to save data for dikson :
# Attempting to save data for bonfim :
# Attempting to save data for petropavlovsk-kamchatskiy :
# Attempting to save data for jieshi :
# Attempting to save data for joshimath :
# Attempting to save data for chor :
# Attempting to save data for waipawa :
# Attempting to save data for turbat :
# Attempting to save data for pisco :
# Attempting to save data for tateyama :
# Attempting to save data for samsun :
# Attempting to save data for tyukhtet :
# Attempting to save data for wahran :
# failed to find all info for wahran, skipping
# Attempting to save data for grand-santi :
# Attempting to save data for tarudant :
# failed to find all info for tarudant, skipping
# Attempting to save data for poya :
# Attempting to save data for havoysund :
# Attempting to save data for umzimvubu :
# failed to find all info for umzimvubu, skipping
# Attempting to save data for kailua :
# Attempting to save data for coacoyul :
# Attempting to save data for santa isabel :
# Attempting to save data for matara :
# Attempting to save data for kyshtovka :
# Attempting to save data for the valley :
# Attempting to save data for jalalpur pirwala :
# Attempting to save data for alekseyevsk :
# Attempting to save data for henties bay :
# Attempting to save data for vaitupu :
# failed to find all info for vaitupu, skipping
# Attempting to save data for alice springs :
# Attempting to save data for jiutai :
# Attempting to save data for aklavik :
# Attempting to save data for mulege :
# Attempting to save data for lolua :
# failed to find all info for lolua, skipping
# Attempting to save data for akdepe :
# Attempting to save data for san isidro :
# Attempting to save data for ponta do sol :
# Attempting to save data for blythe :
# Attempting to save data for madinat sittah uktubar :
# Attempting to save data for itupeva :
# Attempting to save data for faya :
# Attempting to save data for temaraia :
# failed to find all info for temaraia, skipping
# Attempting to save data for torbay :
# Attempting to save data for timra :
# Attempting to save data for gobabis :
# Attempting to save data for lavrentiya :
# Attempting to save data for amberley :
# Attempting to save data for hauterive :
# Attempting to save data for bokspits :
# failed to find all info for bokspits, skipping
# Attempting to save data for khasan :
# Attempting to save data for ketchikan :
# Attempting to save data for tukrah :
# Attempting to save data for balad :
# Attempting to save data for gillette :
# Attempting to save data for saint-francois :
# Attempting to save data for pafos :
# Attempting to save data for shingu :
# Attempting to save data for kerema :
# Attempting to save data for broome :
# Attempting to save data for kenai :
# Attempting to save data for fairbanks :
# Attempting to save data for kalmunai :
# Attempting to save data for asau :
# Attempting to save data for tessalit :
# Attempting to save data for san francisco morazan :
# failed to find all info for san francisco morazan, skipping
# Attempting to save data for karkaralinsk :
# failed to find all info for karkaralinsk, skipping
# Attempting to save data for saryagash :
# Attempting to save data for bilma :
# Attempting to save data for vestmannaeyjar :
# Attempting to save data for calama :
# Attempting to save data for bilibino :
# Attempting to save data for biloela :
# Attempting to save data for azar shahr :
# failed to find all info for azar shahr, skipping
# Attempting to save data for aloleng :
# Attempting to save data for luanda :
# Attempting to save data for huntington :
# Attempting to save data for mount isa :
# Attempting to save data for karratha :
# Attempting to save data for zhigansk :
# Attempting to save data for shache :
# Attempting to save data for moerai :
# Attempting to save data for keti bandar :
# Attempting to save data for ouargaye :
# Attempting to save data for lovington :
# Attempting to save data for haines junction :
# Attempting to save data for iracoubo :
# Attempting to save data for seoul :
# Attempting to save data for bathsheba :
# Attempting to save data for batagay :
# Attempting to save data for louisbourg :
# failed to find all info for louisbourg, skipping
# Attempting to save data for ahuimanu :
# Attempting to save data for baijiantan :
# Attempting to save data for baghdad :
# Attempting to save data for watrous :
# Attempting to save data for tonj :
# Attempting to save data for wembley :
# Attempting to save data for letnyaya stavka :
# Attempting to save data for fenoarivo :
# Attempting to save data for novikovo :
# Attempting to save data for byron bay :
# Attempting to save data for kalomo :
# failed to find all info for kalomo, skipping
# Attempting to save data for chicama :
# Attempting to save data for ondorhaan :
# failed to find all info for ondorhaan, skipping
# Attempting to save data for nagaur :
# Attempting to save data for simao :
# Attempting to save data for valdosta :
# Attempting to save data for dhrangadhra :
# Attempting to save data for tiarei :
# Attempting to save data for port augusta :
# Attempting to save data for northam :
# Attempting to save data for payson :
# Attempting to save data for ayan :
# Attempting to save data for arlit :
# Attempting to save data for koroni :
# Attempting to save data for meulaboh :
# Attempting to save data for victor harbor :
# Attempting to save data for kosh-agach :
# Attempting to save data for sanghar :
# Attempting to save data for bereda :
# Attempting to save data for la asuncion :
# Attempting to save data for port macquarie :
# Attempting to save data for san matias :
# Attempting to save data for pingliang :
# Attempting to save data for poso :
# Attempting to save data for vostok :
# Attempting to save data for acapulco :
# Attempting to save data for okhotsk :
# Attempting to save data for naica :
# Attempting to save data for victoria :
# Attempting to save data for ulladulla :
# Attempting to save data for burriana :
# Attempting to save data for ayat :
# Attempting to save data for mount abu :
# Attempting to save data for grande prairie :
# Attempting to save data for kalabo :
# Attempting to save data for olinda :
# Attempting to save data for oceanside :
# Attempting to save data for pozo colorado :
# Attempting to save data for homer :
# Attempting to save data for beyneu :
# Attempting to save data for pochutla :
# Attempting to save data for camanci :
# failed to find all info for camanci, skipping
# Attempting to save data for gazli :
# Attempting to save data for namibe :
# Attempting to save data for lakes entrance :
# Attempting to save data for ulaangom :
# Attempting to save data for lucea :
# Attempting to save data for melekhovo :
# Attempting to save data for aktash :
# Attempting to save data for kiunga :
# Attempting to save data for san rafael :
# Attempting to save data for mao :
# Attempting to save data for ingham :
# Attempting to save data for mehamn :
# Attempting to save data for linchuan :
# failed to find all info for linchuan, skipping
# Attempting to save data for santa eulalia del rio :
# failed to find all info for santa eulalia del rio, skipping
# Attempting to save data for kayerkan :
# Attempting to save data for vaxjo :
# Attempting to save data for caernarfon :
# Attempting to save data for egvekinot :
# Attempting to save data for charlestown :
# Attempting to save data for tarakan :
# Attempting to save data for port hardy :
# Attempting to save data for kuusamo :
# Attempting to save data for kabalo :
# Attempting to save data for juterbog :
# Attempting to save data for shelburne :
# Attempting to save data for maceio :
# Attempting to save data for sao joao da barra :
# Attempting to save data for ardakan :
# Attempting to save data for wamba :
# Attempting to save data for jianhu :
# Attempting to save data for krasnyy chikoy :
# Attempting to save data for zeya :
# Attempting to save data for bollnas :
# Attempting to save data for villa maria :
# Attempting to save data for balikpapan :
# Attempting to save data for kushima :
# Attempting to save data for belmonte :
# Attempting to save data for pundaguitan :
# Attempting to save data for kieta :
# Attempting to save data for bolungarvik :
# failed to find all info for bolungarvik, skipping
# Attempting to save data for bestobe :
# Attempting to save data for berdigestyakh :
# Attempting to save data for santa ana :
# Attempting to save data for qui nhon :
# Attempting to save data for cazaje :
# failed to find all info for cazaje, skipping
# Attempting to save data for saint-augustin :
# Attempting to save data for zalantun :
# Attempting to save data for klamath falls :
# Attempting to save data for griffith :
# Attempting to save data for fort nelson :
# Attempting to save data for batagay-alyta :
# Attempting to save data for isla mujeres :
# Attempting to save data for porto seguro :
# Attempting to save data for umm kaddadah :
# Attempting to save data for saint-georges :
# Attempting to save data for sorong :
# Attempting to save data for porto novo :
# Attempting to save data for genhe :
# Attempting to save data for mantua :
# Attempting to save data for margate :
# Attempting to save data for beihai :
# Attempting to save data for sinop :
# Attempting to save data for alofi :
# Attempting to save data for komsomolets :
# Attempting to save data for rio grande :
# Attempting to save data for plerin :
# Attempting to save data for satitoa :
# failed to find all info for satitoa, skipping
# Attempting to save data for abu samrah :
# Attempting to save data for capoterra :
# --------------------------------------
# Data Retrieval Complete
# --------------------------------------

# %%
base_df_dict = {
    'City' : names,
    'Cloudiness' : cloudinessess,
    'Country' : countries,
    'Date' : dates,
    'Humidity' : humidities,
    'Lat' : cityLats,
    'Lng' : cityLngs,
    'Max Temp' : temps,
    'Wind Speed' : windSpeeds}

base_df = pd.DataFrame(base_df_dict)
base_df
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Anadyr          90      RU  1587162143        78  64.75  177.48
# 1      Carnarvon          89      AU  1587162149        88 -24.87  113.63
# 2       Saldanha          70      ZA  1587162150        72 -33.01   17.94
# 3     Codrington         100      AU  1587162150        77 -38.27  141.97
# 4        Rikitea           1      PF  1587161996        65 -23.12 -134.97
# ..           ...         ...     ...         ...       ...    ...     ...
# 561  Komsomolets          98      KZ  1587162232        67  53.75   62.07
# 562   Rio Grande           4      BR  1587162037        83 -32.03  -52.10
# 563       Plérin          66      FR  1587162232        87  48.54   -2.78
# 564   Abu Samrah           9      SY  1587162232        43  35.30   37.18
# 565    Capoterra          75      IT  1587162233        87  39.18    8.97
#
#      Max Temp  Wind Speed
# 0       12.20       13.42
# 1       75.20        5.82
# 2       59.00        9.17
# 3       54.73        9.53
# 4       77.18        2.51
# ..        ...         ...
# 561     46.29       15.70
# 562     62.01       10.45
# 563     55.00        1.12
# 564     64.74        5.91
# 565     61.00       11.41
#
# [566 rows x 9 columns]

# %%
base_df.count()
# Out:
# City          566
# Cloudiness    566
# Country       566
# Date          566
# Humidity      566
# Lat           566
# Lng           566
# Max Temp      566
# Wind Speed    566
# dtype: int64

# %%
lat_sorted_df = base_df.sort_values('Lat')
lat_sorted_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 10        Ushuaia          75      AR  1587162150        32 -54.80  -68.30
# 58   Punta Arenas          66      CL  1587161990        71 -53.15  -70.92
# 354  Río Gallegos           0      AR  1587162200        47 -51.62  -69.22
# 122         Bluff          78      NZ  1587162164        93 -46.60  168.33
# 83     Kaitangata         100      NZ  1587162159        86 -46.28  169.85
# ..            ...         ...     ...         ...       ...    ...     ...
# 169      Khatanga           0      RU  1587162041        91  71.97  102.50
# 42      Upernavik           0      GL  1587162154        90  72.79  -56.15
# 375        Dikson           2      RU  1587162203        92  73.51   80.55
# 110       Qaanaaq           0      GL  1587162163        85  77.48  -69.36
# 92   Longyearbyen          75      SJ  1587162160        96  78.22   15.64
#
#      Max Temp  Wind Speed
# 10      53.60        9.17
# 58      50.00        4.70
# 354     55.40       18.34
# 122     52.00        5.99
# 83      53.01       21.99
# ..        ...         ...
# 169      6.31       12.17
# 42      24.67        2.24
# 375      9.55        8.34
# 110     17.87        0.72
# 92      32.00        6.93
#
# [566 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.close()
x_vals = lat_sorted_df['Lat']
y_vals = lat_sorted_df['Max Temp']
plt.scatter(x_vals, y_vals, alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Temperature Fahrenheit')
plt.title('Latitude vs. Temperature')
plt.legend(labels=['City'], loc='lower left')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.close()
x_vals = lat_sorted_df['Lat']
y_vals = lat_sorted_df['Humidity']
plt.scatter(x_vals, y_vals, alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
plt.legend(labels=['City'], loc='lower left')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.close()
x_vals = lat_sorted_df['Lat']
y_vals = lat_sorted_df['Cloudiness']
plt.scatter(x_vals, y_vals, alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
# plt.legend(labels=['City'], loc='best')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.close()
x_vals = lat_sorted_df['Lat']
y_vals = lat_sorted_df['Wind Speed']
plt.scatter(x_vals, y_vals, alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
plt.legend(labels=['City'], loc='upper left')

plt.show()

# %%
plt.close()
x_vals = lat_sorted_df['Lat']
y_vals = lat_sorted_df['Wind Speed']
plt.scatter(x_vals, y_vals, alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
plt.legend(labels=['City'], loc='upper left')

plt.show()

# %%
def linRegresPlt(x_vals, y_vals, labels=['title' , 'y']):
#     x_vals = df['']
#     y_vals = df['']
#     labels = ['title' , 'y']
        
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
    regress_values = x_vals * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(line_eq)
    print(f"The r-squared is: {rvalue}")
    
    plt.close()
    plt.scatter(x_vals, y_vals, alpha=0.5)
    plt.xlabel('Latitude')
    plt.ylabel(labels[1])
    plt.title(labels[0])
    plt.plot(x_vals, regress_values, "r-")
    plt.legend(labels=['Correlation line', 'City'], loc='best')

    plt.show()

# %%
labels = ['Latitude vs. Wind Speed', 'Wind Speed']
linRegresPlt(x_vals=lat_sorted_df['Lat'], labels=labels, y_vals=lat_sorted_df['Wind Speed'])
# Out:
# y = 0.03x + 7.57
# The r-squared is: 0.15533405590414284

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
# north = lat >= 0
# south = lat < 0

# %%
lat_sorted_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 10        Ushuaia          75      AR  1587162150        32 -54.80  -68.30
# 58   Punta Arenas          66      CL  1587161990        71 -53.15  -70.92
# 354  Río Gallegos           0      AR  1587162200        47 -51.62  -69.22
# 122         Bluff          78      NZ  1587162164        93 -46.60  168.33
# 83     Kaitangata         100      NZ  1587162159        86 -46.28  169.85
# ..            ...         ...     ...         ...       ...    ...     ...
# 169      Khatanga           0      RU  1587162041        91  71.97  102.50
# 42      Upernavik           0      GL  1587162154        90  72.79  -56.15
# 375        Dikson           2      RU  1587162203        92  73.51   80.55
# 110       Qaanaaq           0      GL  1587162163        85  77.48  -69.36
# 92   Longyearbyen          75      SJ  1587162160        96  78.22   15.64
#
#      Max Temp  Wind Speed
# 10      53.60        9.17
# 58      50.00        4.70
# 354     55.40       18.34
# 122     52.00        5.99
# 83      53.01       21.99
# ..        ...         ...
# 169      6.31       12.17
# 42      24.67        2.24
# 375      9.55        8.34
# 110     17.87        0.72
# 92      32.00        6.93
#
# [566 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
